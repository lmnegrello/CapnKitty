# %% [markdown]
# <a href="https://colab.research.google.com/github/lmnegrello/CapnKitty/blob/main/Copy_of_Week_1_Homework.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Week 1 Homework
#
# (Be sure to save this to Drive before starting)
#
# For this week we are going to practice requesting information from an API and manipulating it as JSON and as a Dataframe.
#
# We are going to keep working with Collection Builder. Head over to the [Collection Builder Example Projects](https://collectionbuilder.github.io/cb-examples/browse.html) listing and find a site that interests you. Spend some time browsing the website to get acquainted with its contents before proceeding with the questions.

# %%
#The Libraries we will need
import requests
import json
import pandas as pd
from random import randrange

# %%
# @markdown **H1** Find the URL of for the  _metadata.json_ of your selected site and paste it in here.
json_cb_url = "https://abisarah.github.io/A-Fond-Sigh-of-Friendship/assets/data/metadata.json" # @param {"type":"string","placeholder":""}

response_cb = requests.get(json_cb_url)
#all of the data from the sites
total_cb_data = response_cb.json()
#just the 'objects' indexed in the site
objects_cb_data = total_cb_data['objects']
print("Data fetched and JSON constructed!")
# Out:
# Data fetched and JSON constructed!

# %% [markdown]
# **H2** Run the 'show random cell' a few times to get a sense of what kind of data is in your chosen site.

# %%
#Run this a few times to see random entries in the JSON data that you retrieved.
random_entry = randrange(len(objects_cb_data))
print(json.dumps(objects_cb_data[random_entry],indent=2))
# Out:
# {
#   "title": "Eyes Which Never Close",
#   "date": "1892-04-27",
#   "description": "A poem with an embroidered flower in the middle of the page. There seems to be a yellowish stain coming from underneath the flower, this may be glue or just an old stain from age. ",
#   "subject": "embroidery; flower; poem",
#   "location": "niagara",
#   "latitude": "43.07939",
#   "longitude": "-79.0768",
#   "format": "image/png",
#   "reference_url": "https://github.cam/AbiSarah/A-Fond-Sigh-of-Friendship/item.html?id=item4"
# }

# %% [markdown]
# ## Different Fields!
#
# You can create any number of datafields and correpsonding values for those fields with a Collection Builder site. So the results from the output from the cell above will probably have wildly different results from [my site](https://elibtronic.github.io/AIL_Database/data.html) that we worked on in the Workalong notebook.
#
#
# You can see all of these options from grabbing the _facets.json_ URL from a collection builder homepage. Find that URL for your selected site for **H3**

# %%
# @markdown **H3** Find the URL of the facets.json for your selected site and paste it in here.
json_cb_facets_url = "https://abisarah.github.io/A-Fond-Sigh-of-Friendship/assets/data/facets.json" # @param {"type":"string","placeholder":""}

response_cb = requests.get(json_cb_facets_url)
#all of the data from the sites
total_facet_data = response_cb.json()
#just the 'objects' indexed in the site
print("Data fetched and JSON constructed!")
# Out:
# Data fetched and JSON constructed!

# %% [markdown]
# Run the cell below to see what the facets used for this site:

# %%
print(json.dumps(total_facet_data,indent=2))
# Out:
# {
#   "facets": [
#     {
#       "field": "subject",
#       "terms": {
#         "ball": 2,
#         "bear": 1,
#         "bird": 1,
#         "birds": 2,
#         "boy": 3,
#         "branch": 2,
#         "bunny": 1,
#         "butterflies": 1,
#         "canteen": 1,
#         "chair": 2,
#         "checking": 1,
#         "circle": 1,
#         "collage": 2,
#         "dog": 1,
#         "doghouse": 1,
#         "dogs": 1,
#         "embroidery": 1,
#         "fence": 1,
#         "flower": 1,
#         "flowers": 3,
#         "framed photos": 1,
#         "grass": 1,
#         "gun": 1,
#         "hat": 2,
#         "horse": 1,
#         "house": 1,
#         "leaf stained page": 1,
#         "leaves": 2,
#         "man": 2,
#         "newspaper clipping": 2,
#         "piano": 1,
#         "poem": 6,
#         "rope": 1,
#         "sheet music": 1,
#         "stickers": 3,
#         "stool": 1,
#         "table": 2,
#         "tree trunk": 1,
#         "trees": 1,
#         "utensils": 2,
#         "water pitcher": 2,
#         "woman": 1
#       }
#     },
#     {
#       "field": "creator",
#       "terms": {}
#     },
#     {
#       "field": "format",
#       "terms": {
#         "image/jpg": 7,
#         "image/png": 9
#       }
#     }
#   ]
# }

# %% [markdown]
# **H3** Try to read the JSON that is displayed to the screen. What possible facets are there in the the data. Fill them in the markdown list in the cell below. Add as many entries as you need to describe the site

# %% [markdown]
# Facets in my site are:
# - facet 1 "subject"
# - facet 2 "creator"
# - facet 3 "format"

# %% [markdown]
# **H4** Which facet shows up the most for your selected site? Put your answer in the cell below

# %% [markdown]
# This facet that shows up the most is "subject" it is used 14 times on my selected site.

# %% [markdown]
# **H5** Turn the site _metadata.json_ data into a dataframe by completing the cell below. Part of it is written for you. You just need to modify line 4.

# %%
#H5

cb_data = pd.read_json(json_cb_url)
cb_normalized = pd.json_normalize(cb_data['objects'])
cb_normalized
# Out:
#                      title        date  \
# 0               The Attack        1884
# 1               The Defeat        1884
# 2                   A Bird      c.1892
# 3   Eyes Which Never Close  1892-04-27
# 4              In Memoriam  1859-08-22
# 5      The Boy and The Dog      c.1855
# 6                Two Birds      c.1855
# 7          The Howling Dog      c.1855
# 8    The Pained Face Horse      c.1855
# 9             A Shaky Hand  1931-03-28
# 10              Bunny Ears  1936-08-16
# 11                    Help  1936-08-16
# 12             Marry Harry  1926-03-18
# 13                Mrs Hill  1926-07-22
# 14           The Last Page  1937-02-07
# 15     The  True Last Page  1937-09-22
#
#                                           description  \
# 0        A boy eating at a table, with determination.
# 1   A boy exhausted after eating, sleeping at the ...
# 2   A bird on a branch, looking up to the left. Th...
# 3   A poem with an embroidered flower in the middl...
# 4   A collage of newspaper clippings, in memory of...
# 5   A boy lying on top of a walking dog, with a ca...
# 6   There are two birds sitting on tree branches, ...
# 7   A dog howling at the sky, chained to his dogho...
# 8   A drawing of a horse with a pained or startled...
# 9   A poem from the recipient's Grandmother, with ...
# 10  A poem with a small drawing of a round bunny r...
# 11  A drawing of a man being chased by a bear in a...
# 12  A poem written in a circle, telling the recipi...
# 13  A drawing of a woman playing piano. There are ...
# 14  A poem talking about being the last person to ...
# 15  A poem written on the inside of the back cover...
#
#                                               subject          location  \
# 0    boy; ball; table; chair; water pitcher; utensils           niagara
# 1    boy; ball; table; chair; water pitcher; utensils           niagara
# 2                     bird; branch; leaf stained page           niagara
# 3                            embroidery; flower; poem           niagara
# 4   collage; newspaper clipping; checking; flowers...           niagara
# 5                             dog; boy; canteen; rope           niagara
# 6                               birds; branch; leaves           niagara
# 7   dogs; man; hat; gun; tree trunk; doghouse; lea...           niagara
# 8                  collage; horse; newspaper clipping           niagara
# 9                               birds; stickers; poem  niagara chippawa
# 10                     bunny; flowers; stickers; poem  niagara chippawa
# 11                man; bear; trees; house; fence; hat  niagara chippawa
# 12                                       poem; circle  niagara chippawa
# 13    piano; stool; framed photos; sheet music; woman  niagara chippawa
# 14                            poem; flowers; stickers  niagara chippawa
# 15                                               poem  niagara chippawa
#
#      latitude    longitude     format  \
# 0   43.079387  -79.0767583  image/png
# 1   43.079387     -79.0768  image/png
# 2    43.07939     -79.0768  image/png
# 3    43.07939     -79.0768  image/png
# 4    43.07939     -79.0768  image/png
# 5    43.07939     -79.0768  image/png
# 6    43.07939     -79.0768  image/png
# 7    43.07939     -79.0768  image/png
# 8    43.07939     -79.0768  image/png
# 9   43.055158   -79.057393  image/jpg
# 10   43.05516     -79.0574  image/jpg
# 11   43.05516     -79.0574  image/jpg
# 12   43.05516     -79.0574  image/jpg
# 13   43.05516     -79.0574  image/jpg
# 14   43.05516     -79.0574  image/jpg
# 15   43.05516     -79.0574  image/jpg
#
#                                         reference_url
# 0   https://github.cam/AbiSarah/A-Fond-Sigh-of-Fri...
# 1   https://github.cam/AbiSarah/A-Fond-Sigh-of-Fri...
# 2   https://github.cam/AbiSarah/A-Fond-Sigh-of-Fri...
# 3   https://github.cam/AbiSarah/A-Fond-Sigh-of-Fri...
# 4   https://github.cam/AbiSarah/A-Fond-Sigh-of-Fri...
# 5   https://github.cam/AbiSarah/A-Fond-Sigh-of-Fri...
# 6   https://github.cam/AbiSarah/A-Fond-Sigh-of-Fri...
# 7   https://github.cam/AbiSarah/A-Fond-Sigh-of-Fri...
# 8   https://github.cam/AbiSarah/A-Fond-Sigh-of-Fri...
# 9   https://github.cam/AbiSarah/A-Fond-Sigh-of-Fri...
# 10  https://github.cam/AbiSarah/A-Fond-Sigh-of-Fri...
# 11  https://github.cam/AbiSarah/A-Fond-Sigh-of-Fri...
# 12  https://github.cam/AbiSarah/A-Fond-Sigh-of-Fri...
# 13  https://github.cam/AbiSarah/A-Fond-Sigh-of-Fri...
# 14  https://github.cam/AbiSarah/A-Fond-Sigh-of-Fri...
# 15  https://github.cam/AbiSarah/A-Fond-Sigh-of-Fri...

# %%
#Run this a few times to see random entries in your dataframe
cb_normalized.sample(10)
# Out:
#                      title        date  \
# 1               The Defeat        1884
# 12             Marry Harry  1926-03-18
# 11                    Help  1936-08-16
# 13                Mrs Hill  1926-07-22
# 3   Eyes Which Never Close  1892-04-27
# 0               The Attack        1884
# 14           The Last Page  1937-02-07
# 9             A Shaky Hand  1931-03-28
# 7          The Howling Dog      c.1855
# 6                Two Birds      c.1855
#
#                                           description  \
# 1   A boy exhausted after eating, sleeping at the ...
# 12  A poem written in a circle, telling the recipi...
# 11  A drawing of a man being chased by a bear in a...
# 13  A drawing of a woman playing piano. There are ...
# 3   A poem with an embroidered flower in the middl...
# 0        A boy eating at a table, with determination.
# 14  A poem talking about being the last person to ...
# 9   A poem from the recipient's Grandmother, with ...
# 7   A dog howling at the sky, chained to his dogho...
# 6   There are two birds sitting on tree branches, ...
#
#                                               subject          location  \
# 1    boy; ball; table; chair; water pitcher; utensils           niagara
# 12                                       poem; circle  niagara chippawa
# 11                man; bear; trees; house; fence; hat  niagara chippawa
# 13    piano; stool; framed photos; sheet music; woman  niagara chippawa
# 3                            embroidery; flower; poem           niagara
# 0    boy; ball; table; chair; water pitcher; utensils           niagara
# 14                            poem; flowers; stickers  niagara chippawa
# 9                               birds; stickers; poem  niagara chippawa
# 7   dogs; man; hat; gun; tree trunk; doghouse; lea...           niagara
# 6                               birds; branch; leaves           niagara
#
#      latitude    longitude     format  \
# 1   43.079387     -79.0768  image/png
# 12   43.05516     -79.0574  image/jpg
# 11   43.05516     -79.0574  image/jpg
# 13   43.05516     -79.0574  image/jpg
# 3    43.07939     -79.0768  image/png
# 0   43.079387  -79.0767583  image/png
# 14   43.05516     -79.0574  image/jpg
# 9   43.055158   -79.057393  image/jpg
# 7    43.07939     -79.0768  image/png
# 6    43.07939     -79.0768  image/png
#
#                                         reference_url
# 1   https://github.cam/AbiSarah/A-Fond-Sigh-of-Fri...
# 12  https://github.cam/AbiSarah/A-Fond-Sigh-of-Fri...
# 11  https://github.cam/AbiSarah/A-Fond-Sigh-of-Fri...
# 13  https://github.cam/AbiSarah/A-Fond-Sigh-of-Fri...
# 3   https://github.cam/AbiSarah/A-Fond-Sigh-of-Fri...
# 0   https://github.cam/AbiSarah/A-Fond-Sigh-of-Fri...
# 14  https://github.cam/AbiSarah/A-Fond-Sigh-of-Fri...
# 9   https://github.cam/AbiSarah/A-Fond-Sigh-of-Fri...
# 7   https://github.cam/AbiSarah/A-Fond-Sigh-of-Fri...
# 6   https://github.cam/AbiSarah/A-Fond-Sigh-of-Fri...

# %% [markdown]
# **H6** This is for bonus!
# Try to write a pandas statement that will display your answer from **H4**. There are plenty of ways to do this, so feel free to use your imagination. What I have started for you here might not work, so feel free to change it as needed.

# %%
cb_normalized["subject"].count()

print(cb_normalized["subject"].value_counts())
# Out:
# subject
# boy; ball; table; chair; water pitcher; utensils               2
# bird; branch; leaf stained page                                1
# embroidery; flower; poem                                       1
# collage; newspaper clipping; checking; flowers; butterflies    1
# dog; boy; canteen; rope                                        1
# birds; branch; leaves                                          1
# dogs; man; hat; gun; tree trunk; doghouse; leaves; grass       1
# collage; horse; newspaper clipping                             1
# birds; stickers; poem                                          1
# bunny; flowers; stickers; poem                                 1
# man; bear; trees; house; fence; hat                            1
# poem; circle                                                   1
# piano; stool; framed photos; sheet music; woman                1
# poem; flowers; stickers                                        1
# poem                                                           1
# Name: count, dtype: int64

# %% [markdown]
# ## All Done!
#
# Congrats you are finished with this week's work. First save as PDF so that you can upload to the Course site then click the `Share` button above and enter `libraryjuicepresspython@gmail.com` so I can get a shared copy of your work.
